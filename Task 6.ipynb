# %% [markdown]
# **MANTHA SRI HARSHA**

# %%
# !unzip complaints.csv.zip
# Out:
# Archive:  complaints.csv.zip
#   inflating: complaints.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('complaints.csv')

data.head()
# Out:
# <ipython-input-7-f1f779e0e42b>:6: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('complaints.csv')
#   Date received                                            Product  \
# 0    2023-04-21                                    Debt collection
# 1    2023-04-15                                    Debt collection
# 2    2023-04-15  Credit reporting, credit repair services, or o...
# 3    2023-04-14  Credit reporting, credit repair services, or o...
# 4    2023-04-14  Credit reporting, credit repair services, or o...
#
#         Sub-product                                 Issue  \
# 0     Mortgage debt    False statements or representation
# 1     I do not know     Attempts to collect debt not owed
# 2  Credit reporting           Improper use of your report
# 3  Credit reporting  Incorrect information on your report
# 4  Credit reporting  Incorrect information on your report
#
# ...

# %%
print(data.shape)
# Out:
# (3572479, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3572479 entries, 0 to 3572478
# Data columns (total 18 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   Date received                 object
#  1   Product                       object
#  2   Sub-product                   object
#  3   Issue                         object
#  4   Sub-issue                     object
#  5   Consumer complaint narrative  object
#  6   Company public response       object
#  7   Company                       object
#  8   State                         object
#  9   ZIP code                      object
#  10  Tags                          object
#  11  Consumer consent provided?    object
#  12  Submitted via                 object
#  13  Date sent to company          object
#  14  Company response to consumer  object
#  15  Timely response?              object
#  16  Consumer disputed?            object
#  17  Complaint ID                  int64
# ...

# %%
df = data['Product']

# %%
pd.DataFrame(df.unique())
# Out:
#                                                     0
# 0                                     Debt collection
# 1   Credit reporting, credit repair services, or o...
# 2                         Credit card or prepaid card
# 3                               Vehicle loan or lease
# 4   Money transfer, virtual currency, or money ser...
# 5                         Checking or savings account
# 6                                        Student loan
# 7                                            Mortgage
# 8                                    Credit reporting
# 9           Payday loan, title loan, or personal loan
# 10                                    Money transfers
# 11                                        Credit card
# 12                            Bank account or service
# 13                                        Payday loan
# 14                                      Consumer Loan
# 15                                       Prepaid card
# ...

# %%
df2 = pd.Categorical(df)

# %%
df_cat = df2.remove_categories(['Virtual currency', 'Other financial service','Prepaid card','Payday loan','Bank account or service','Credit card','Money transfers','Payday loan, title loan, or personal loan','Credit reporting','Student loan','Checking or savings account','Money transfer, virtual currency, or money service','Vehicle loan or lease','Credit card or prepaid card'])

# %%
df_cat.dropna()
# Out:
# ['Debt collection', 'Debt collection', 'Credit reporting, credit repair services, or ..., 'Credit reporting, credit repair services, or ..., 'Credit reporting, credit repair services, or ..., ..., 'Mortgage', 'Mortgage', 'Mortgage', 'Mortgage', 'Credit reporting, credit repair services, or ...]
# Length: 2694147
# Categories (4, object): ['Consumer Loan', 'Credit reporting, credit repair services, or ...,
#                          'Debt collection', 'Mortgage']

# %%
pd.DataFrame(df_cat.unique())
# Out:
#                                                    0
# 0                                    Debt collection
# 1  Credit reporting, credit repair services, or o...
# 2                                                NaN
# 3                                           Mortgage
# 4                                      Consumer Loan
